# %% [markdown]
# THEORY QUESTION
#
#  What is Object-Oriented Programming (OOP)+
#
#  What is a class in OOP+
#
#  What is an object in OOP+
#
#  What is the difference between abstraction and encapsulation+
#
#  What are dunder methods in Python+
#
#  Explain the concept of inheritance in OOPH
#
#  What is polymorphism in OOP+
#
#  How is encapsulation achieved in Python+
#
#  What is a constructor in Python+
#
#  What are class and static methods in Python+
#
#  What is method overloading in Python+
#
#  What is method overriding in OOP+
#
#  What is a property decorator in Python+
#
#  Why is polymorphism important in OOP+
#
#  What is an abstract class in Python+
#
#  What are the advantages of OOP+
#
#  What is the difference between a class variable and an instance variable+
#
#  What is multiple inheritance in Python+
#
#  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in PythonH
#
#  What is the significance of the ‘super()’ function in Python+
#
#  What is the significance of the __del__ method in Python+
#
#  What is the difference between @staticmethod and @classmethod in Python+
#
#  How does polymorphism work in Python with inheritance+
#
#  What is method chaining in Python OOP+
#
#  What is the purpose of the __call__ method in Python?
#
#
# PRACTICAL QUESTIONS
#
#
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".
#
#
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.
#
#
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
#
#
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.
#
#
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().
#
#
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
#
#
# 8. Implement a class Person with a class method to count the total number of persons created.
#
#
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".
#
#
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
#
#
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
#
#
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
#
#
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.
#
#
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
# Practical Questions
# Java + DSAPwskills
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
#
#
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
#
#
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
#
#
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.
#
# ANSWERS>>
#
#
#
#
# 1. >> OOP is a programming paradigm based on the concept of objects, which are instances of classes. It allows for organizing code into reusable and modular components. It focuses on data and behavior, and the four pillars are:
#
#     Encapsulation
#
#     Abstraction
#
#     Inheritance
#
#     Polymorphism
#
#
#
# 2. >> A class is a blueprint or template for creating objects. It defines attributes (variables) and methods (functions) that the created objects will have.
#
# class Car:
#     def __init__(self, brand):
#         self.brand = brand
#     def drive(self):
#         print(f"{self.brand} is driving")
#
#
# 3. >> An object is an instance of a class. It holds actual values for the properties defined in the class.
#
# my_car = Car("Toyota")  # my_car is an object
# my_car.drive()
#
#
# 4. >>    Abstraction hides implementation details, showing only relevant functionality.
#
#     Encapsulation hides data by bundling it with methods that restrict direct access.
#
#
#
# 5.  >>   Dunder = “Double underscore”. These are special methods with __name__
# format like __init__, __str__, etc. They enable Python's built-in behaviors (like object printing, operator overloading).
#
# 6. >> Inheritance allows a class (child) to inherit attributes and methods from another class (parent), promoting code reuse.
#
# class Animal:
#     def speak(self): print("Animal speaks")
#
# class Dog(Animal):
#     def bark(self): print("Dog barks")
#
#
# 7. >> Polymorphism allows the same interface (method name) to behave differently across classes.
#
# class Cat:
#     def sound(self):
#     print("Meow")
#
# class Dog:
#     def sound(self):
#      print("Bark")
#
# for animal in [Cat(), Dog()]:
#     animal.sound()  # same method name, different behavior
#
#
# 8. >> By making attributes private (using _ or __) and providing getter/setter methods.
#
# class BankAccount:
#     def __init__(self):
#         self.__balance = 0
#
#     def deposit(self, amount):
#         self.__balance += amount
#
#
# 9. >> __init__ is the constructor. It runs automatically when a class is instantiated.
#
# class Person:
#     def __init__(self, name):
#         self.name = name
#
#     classmethod: Takes cls as the first argument. Can access/modify class state.
#
#     staticmethod: No default self or cls. It’s just a utility function.
#
# class Test:
#     @classmethod
#     def show(cls): print("Class method")
#
#     @staticmethod
#     def util(): print("Static method")
#
#
# 10. >> Python doesn't support method overloading in the traditional sense. You can simulate it by default arguments or *args.
#
# def greet(name=None):
#     if name:
#         print(f"Hello, {name}")
#     else:
#         print("Hello")
#
#
# 11. >> When a subclass provides a specific implementation of a method already defined in the parent class.
# 🔹 What is a property decorator in Python?
#
# @property allows you to define getter/setter in a clean way.
#
# class Circle:
#     def __init__(self, radius):
#         self._radius = radius
#
#     @property
#     def radius(self): return self._radius
#
#     @radius.setter
#     def radius(self, value): self._radius = value
#
#
# 12. >> It allows writing flexible and scalable code. One function can handle different types of objects, which supports extensibility.
#
# 13. >> An abstract class cannot be instantiated and may contain abstract methods that must be implemented in derived classes.
#
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#     @abstractmethod
#     def speak(self): pass
#
#  14. >> Advantages of OOP
#
#     Modularity
#
#     Reusability
#
#     Scalability
#
#     Maintainability
#
#     Real-world modeling
#
#
# 15. >>    Class variable: Shared across all instances.
#
#     Instance variable: Unique to each object.
#
# class A:
#     x = 10           # class variable
#     def __init__(self):
#         self.y = 20   # instance variable
#
#
# 16. >> When a class inherits from more than one parent class.
#
# class A: pass
# class B: pass
# class C(A, B): pass  # Multiple Inheritance
#
#
# 17. >>    __str__: User-friendly string (for print()).
#
#     __repr__: Developer-friendly string (for repr() or debugging).
#
# 🔹 Significance of super() in Python
#
# super() gives access to methods of a parent class, commonly used in constructors to initialize the base class.
# 🔹 Significance of __del__ method in Python
#
# __del__ is a destructor that gets called when an object is deleted or garbage collected.
# 🔹 Difference between @staticmethod and @classmethod
#
#     @staticmethod: Doesn’t receive instance or class reference.
#
#     @classmethod: Receives the class (cls) as an argument.
#
#
# 18. >> A parent class reference can call methods that are overridden in child classes, allowing dynamic behavior at runtime.
# 🔹 What is method chaining in Python OOP?
#
# Returning self from a method allows chaining multiple method calls.
#
# class Builder:
#     def set_name(self, name): self.name = name; return self
#     def set_age(self, age): self.age = age; return self
#
# obj = Builder().set_name("John").set_age(30)
#
# 🔹 Purpose of the __call__ method in Python
#
# Makes an object callable like a function.
#
# class Adder:
#     def __call__(self, a, b):
#         return a + b
#
# add = Adder()
# print(add(2, 3))  # Works like a function
#
# If you want code examples or analogies for any of these, let me know!

# %%
## 1. Create a parent class Animal with a method speak() that prints a generic message.
## Create a child class Dog that overrides the speak() method to print "Bark!"
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Bark!")

## 2. Abstract class Shape with method area(). Derive Circle and Rectangle from it.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

## 3. Multi-level inheritance: Vehicle -> Car -> ElectricCar
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

## 4. Demonstrate polymorphism: Bird -> Sparrow, Penguin
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly")

## 5. Encapsulation: BankAccount with private balance
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount

    def check_balance(self):
        return self.__balance

## 6. Runtime polymorphism: Instrument -> Guitar, Piano
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

## 7. Class with classmethod and staticmethod
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

## 8. Class Person with a counter for number of persons created
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

## 9. Class Fraction with overridden __str__ method
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

## 10. Operator overloading: Vector class with __add__
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

## 11. Person class with greet method
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

## 12. Student class with average_grade method
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

## 13. Rectangle with set_dimensions and area methods
class Rectangle:
    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

## 14. Employee with calculate_salary, Manager adds bonus
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus=0):
        base = super().calculate_salary(hours, rate)
        return base + bonus
